# %% [markdown]
# ## EXPERIMENT 1

# %% [markdown]
# TO PERFORM ANY 5 PANDAS , MATRPLOTLIB AND NUMPY OPERATIONS

# %%
# IMPORTING DEPENDENCIES
# Out:
# Running cells with '.venv (Python 3.13.7)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Kata/Desktop/code/epidemology-Project/code/code/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
